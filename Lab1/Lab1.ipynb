# %% [markdown]
# # Лабораторна робота №1
#
# ## Підготовка робочого середовища
#
# **Студент:** Люлько Станіслав
# **Група:** МІТ-31
# **Дата:** 18.09.2026

# %% [markdown]
# ## Мій перший Notebook
#
# Jupyter Notebook дозволяє поєднувати **Python-код**
# та *текстові пояснення*.

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
student_name = "Люлько Станіслав"
group = "МІТ-31"
print("Студент:", student_name)
print("Група:", group)
# Out:
# Студент: Люлько Станіслав
# Група: МІТ-31

# %%
integer_value = 10
float_value = 3.14
text_value = "Data Science"
boolean_value = True
print(integer_value, type(integer_value))
print(float_value, type(float_value))
print(text_value, type(text_value))
print(boolean_value, type(boolean_value))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Data Science <class 'str'>
# True <class 'bool'>

# %%
a = 15
b =4
print("Сума:", a + b)
print("Різниця:", a - b)
print("Добуток:", a * b)
print("Частка:", a / b)
print("Ціле ділення:", a // b)
print("Залишок від ділення:", a % b)
print("Піднесення до степеня:", a ** b)
# Out:
# Сума: 19
# Різниця: 11
# Добуток: 60
# Частка: 3.75
# Ціле ділення: 3
# Залишок від ділення: 3
# Піднесення до степеня: 50625

# %%
values = [10, 20, 30, 40, 50]
print("Список значень:", values)
print("Виведення першого елемента:", values[0])
print("Виведення останнього елемента:", values[-1])
print("Визначення довжини списку:", len(values))
print("Додавання нового елемента до списку:", values.append(60))
print("Список після додавання нового елемента:", values)
# Out:
# Список значень: [10, 20, 30, 40, 50]
# Виведення першого елемента: 10
# Виведення останнього елемента: 50
# Визначення довжини списку: 5
# Додавання нового елемента до списку: None
# Список після додавання нового елемента: [10, 20, 30, 40, 50, 60]

# %%
import sys

print("Python version:")
print(sys.version)

print("\nPython executable:")
print(sys.executable)
# Out:
# Python version:
# 3.14.7 (v3.14.7:823f0323ee6, Aug  5 2026, 07:07:01) [Clang 21.0.0 (clang-2100.1.1.101)]
#
# Python executable:
# /Users/staslulko/Documents/GitHub/data-mining/.venv/bin/python

# %%
x = 100

# %%
print("Значення змінної x:", x)
# Out:
# Значення змінної x: 100

# %%
print("Значення змінної x:", x)
# Out:
# Значення змінної x: 100
